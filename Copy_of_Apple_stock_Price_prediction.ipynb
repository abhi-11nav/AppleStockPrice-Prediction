# %% [markdown]
# <a href="https://colab.research.google.com/github/abhi-11nav/AppleStockPrice-Prediction/blob/main/Copy_of_Apple_stock_Price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Credits
#
# https://www.kaggle.com/datasets/suyashlakhani/apple-stock-prices-20152020

# %%
# Accesing data from github 

# !git clone https://github.com/abhi-11nav/AppleStockPrice-Prediction.git
# Out:
# Cloning into 'AppleStockPrice-Prediction'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %%
# Importing the data

import pandas as pd 
import numpy as np

data = pd.read_csv("/content/AppleStockPrice-Prediction/AAPL.csv.xls")

# %%
data.head()
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# 1  131.86  30733309  121.438354  121.595013  120.811718  121.512076
# 2  131.23  50884452  120.056069  121.134251  119.705890  120.931516
# 3  131.20  32112797  120.291057  121.078960  119.844118  120.903870
# 4  129.86  33667627  119.761181  120.401640  119.171406  119.669029
#
#    adjVolume  divCash  splitFactor
# 0   45833246      0.0          1.0
# 1   30733309      0.0          1.0
# ...

# %%
data['symbol'].value_counts()
# Out:
# AAPL    1258
# Name: symbol, dtype: int64

# %%
data.tail()
# Out:
#       Unnamed: 0 symbol                       date   close    high       low  \
# 1253        1253   AAPL  2020-05-18 00:00:00+00:00  314.96  316.50  310.3241
# 1254        1254   AAPL  2020-05-19 00:00:00+00:00  313.14  318.52  313.0100
# 1255        1255   AAPL  2020-05-20 00:00:00+00:00  319.23  319.52  316.2000
# 1256        1256   AAPL  2020-05-21 00:00:00+00:00  316.85  320.89  315.8700
# 1257        1257   AAPL  2020-05-22 00:00:00+00:00  318.89  319.23  315.3500
#
#         open    volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  \
# 1253  313.17  33843125    314.96   316.50  310.3241   313.17   33843125
# 1254  315.03  25432385    313.14   318.52  313.0100   315.03   25432385
# 1255  316.68  27876215    319.23   319.52  316.2000   316.68   27876215
# 1256  318.66  25672211    316.85   320.89  315.8700   318.66   25672211
# 1257  315.77  20450754    318.89   319.23  315.3500   315.77   20450754
#
#       divCash  splitFactor
# 1253      0.0          1.0
# ...

# %%
data['high'].plot(figsize=(12,5))
data['low'].plot(figsize=(12,5))

# %%
data['high'].plot(xlim=['2016-05-22','2020-05-22'],ylim=[100,400]figsize=(12,5))

# %%
data.head()
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# 1  131.86  30733309  121.438354  121.595013  120.811718  121.512076
# 2  131.23  50884452  120.056069  121.134251  119.705890  120.931516
# 3  131.20  32112797  120.291057  121.078960  119.844118  120.903870
# 4  129.86  33667627  119.761181  120.401640  119.171406  119.669029
#
#    adjVolume  divCash  splitFactor
# 0   45833246      0.0          1.0
# 1   30733309      0.0          1.0
# ...

# %%
data['date']  = pd.to_datetime(data['date'], format="%Y-%m-%d")

# %%
# Changing the index 

data.set_index('date')
# Out:
#                            Unnamed: 0 symbol    close     high       low  \
# date
# 2015-05-27 00:00:00+00:00           0   AAPL  132.045  132.260  130.0500
# 2015-05-28 00:00:00+00:00           1   AAPL  131.780  131.950  131.1000
# 2015-05-29 00:00:00+00:00           2   AAPL  130.280  131.450  129.9000
# 2015-06-01 00:00:00+00:00           3   AAPL  130.535  131.390  130.0500
# 2015-06-02 00:00:00+00:00           4   AAPL  129.960  130.655  129.3200
# ...                               ...    ...      ...      ...       ...
# 2020-05-18 00:00:00+00:00        1253   AAPL  314.960  316.500  310.3241
# 2020-05-19 00:00:00+00:00        1254   AAPL  313.140  318.520  313.0100
# 2020-05-20 00:00:00+00:00        1255   AAPL  319.230  319.520  316.2000
# 2020-05-21 00:00:00+00:00        1256   AAPL  316.850  320.890  315.8700
# 2020-05-22 00:00:00+00:00        1257   AAPL  318.890  319.230  315.3500
#
#                              open    volume    adjClose     adjHigh  \
# date
# ...
